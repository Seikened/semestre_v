# %% [markdown]
# # EVOLUCIÓN DIFERENCIAL
#
# Determinar mediante la ED el mínimo global de la fucnción Easom en dos variables
#
# $$f(x,y) = -\cos(x)\cos(y)e^{-(x-\pi)^2-(y-\pi)^2}$$
#
# El espacio de busqueda será $(x,y) \in [-5,5]$ y el valor mínimo global es $f(\pi,\pi) = -1$.

# %%
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
import  random

pio.renderers.default = "browser"  # también puedes probar "vscode"


def easom_function(x, y):
    return -np.cos(x) * np.cos(y) * np.exp(-((x - np.pi) ** 2 + (y - np.pi) ** 2))



max_ = 5
min_ = -max_

x = np.linspace(min_, max_, 100)
y = np.linspace(min_, max_, 100)
X,Y = np.meshgrid(x,y)
Z = easom_function(X,Y)




fig = go.Figure(data=[go.Surface(z=Z, x=X, y=Y)])
fig.show()

# %%
import numpy as np

# 1. Área de intercambio térmico (A)
def area_intercambio_termico(Di, L):
    A = np.pi * Di * L
    return A

# Ejemplo (puedes cambiarlo)
A = area_intercambio_termico(Di=0.05, L=1.2)


# 2. Coeficiente global de transferencia de calor (U)
def coef_transf_calor(U=500):
    return U  # W/m²·K

U = coef_transf_calor(U=500)


# 3. Capacidad calorífica del fluido (C)  -> usar por fluido: Ch, Cc
def capacidad_calorifica(m, cp=4180):
    C = m * cp
    return C

# Ejemplo (puedes cambiarlo)
m_hot = 0.12
m_cold = 0.10
Ch = capacidad_calorifica(m=m_hot, cp=4180)
Cc = capacidad_calorifica(m=m_cold, cp=4180)


# 4. Capacidad mínima y máxima (Cmin, Cmax)
def capacidades_min_max(Ch, Cc):
    Cmin = min(Ch, Cc)
    Cmax = max(Ch, Cc)
    return Cmin, Cmax

Cmin, Cmax = capacidades_min_max(Ch=Ch, Cc=Cc)


# 5. Razón de capacidades (Cr = Cmin/Cmax)
def razon_capacidades(Cmin, Cmax):
    Cr = Cmin / Cmax
    return Cr

Cr = razon_capacidades(Cmin=Cmin, Cmax=Cmax)


# 6. Número de unidades de transferencia (NTU)
def numero_unidades_transf(U, A, Cmin):
    NTU = (U * A) / Cmin
    return NTU

NTU = numero_unidades_transf(U=U, A=A, Cmin=Cmin)


# 7. Eficiencia del intercambiador (η, contracorriente)
def eficiencia_intercambiador(NTU, Cr, tol=1e-8):
    x = NTU * (1.0 - Cr)
    # Caso límite cuando Cr -> 1 para evitar inestabilidad numérica
    if abs(1.0 - Cr) < 1e-8:
        eta = NTU / (1.0 + NTU)
    else:
        eta = (1.0 - np.exp(-x)) / (1.0 - Cr * np.exp(-x))
    # Saneamiento numérico ligero
    eta = max(min(eta, 1.0 - tol), tol)
    return eta

eta = eficiencia_intercambiador(NTU=NTU, Cr=Cr)


# 8. Calor transferido (Q)
def calor_transferido(eta, Cmin, Th_in=80.0, Tc_in=20.0):
    Q = eta * Cmin * (Th_in - Tc_in)
    return Q

Q = calor_transferido(eta=eta, Cmin=Cmin, Th_in=80.0, Tc_in=20.0)


# 9. Temperaturas de salida
def temperaturas_salida(Q, Ch, Cc, Th_in=80.0, Tc_in=20.0):
    Th_out = Th_in - Q / Ch
    Tc_out = Tc_in + Q / Cc
    return Th_out, Tc_out

Th_out, Tc_out = temperaturas_salida(Q=Q, Ch=Ch, Cc=Cc, Th_in=80.0, Tc_in=20.0)


# 10. Restricciones que debes revisar (versión ligera)
def restricciones(Di, Do, L, m_hot, m_cold, Th_out, Tc_out, eta):
    ok = True
    msgs = []

    if not (0.01 <= Di <= 0.05): 
        ok = False
        msgs.append("Di fuera de rango [0.01, 0.05]")
    if not (0.015 <= Do <= 0.06): 
        ok = False
        msgs.append("Do fuera de rango [0.015, 0.06]")
    if not (Do > Di): 
        ok = False
        msgs.append("Geometría inválida: Do debe ser > Di")
    if not (1.0 <= L <= 10.0): 
        ok = False
        msgs.append("L fuera de rango [1, 10]")
    if not (0.05 <= m_hot <= 0.5): 
        ok = False
        msgs.append("ṁh fuera de rango [0.05, 0.5]")
    if not (0.05 <= m_cold <= 0.5): 
        ok = False
        msgs.append("ṁc fuera de rango [0.05, 0.5]")
    if not (Th_out > 20.0): 
        ok = False
        msgs.append("Th_out debe ser > Tc_in (20°C)")
    if not (0.0 < eta < 1.0): 
        ok = False
        msgs.append("η debe estar en (0, 1)")
        
    return ok, msgs

# Ejemplo de restricción con un Do y L cualquiera:
Do = 0.055
L = 1.2
ok, msgs = restricciones(Di=0.05, Do=Do, L=L,
                         m_hot=m_hot, m_cold=m_cold,
                         Th_out=Th_out, Tc_out=Tc_out, eta=eta)

# %%
# INICIALIZACIÓN DE POBLACION
def iniciar_poblacion(tamaño_poblacion : int,tamaño_individuo : int, Imin, Imax):
    poblacion = np.zeros((tamaño_poblacion, tamaño_individuo))
    for i in range(tamaño_poblacion):
        individuo = np.zeros((tamaño_individuo))
        for j in range(tamaño_individuo):
            individuo[j] = random.uniform(Imin, Imax)
        poblacion[i] = individuo
    return poblacion

# %%
# FUNCION DE EVALUACION
def evaluar(poblacion):
    n = len(poblacion)
    fitness = np.zeros((n))
    for i in range(n):
        x = poblacion[i][0]
        y = poblacion[i][1]
        fitness[i] = easom_function(x, y)
    return fitness

# %%
# FUNCION DE MUTACION
def mutacion(poblacion, tasa_mutacion,indice):
    F = tasa_mutacion
    n = len(poblacion)
    indices = list(range(n))
    indices.remove(indice)

    r1 = random.choice(indices)
    indices.remove(r1)
    r2 = random.choice(indices)
    indices.remove(r2)
    r3 = random.choice(indices)
    
    
    vector_mutante = np.zeros((poblacion.shape[1]))
    
    for i in range(poblacion.shape[1]):
        vector_mutante[i] = poblacion[r1][i] + F * (poblacion[r2][i] - poblacion[r3][i])
        
    return vector_mutante

# %%
# FUNCION DE CRUZA
def cruza(individuo, vector_mutante, tasa_cruza):
    CR = tasa_cruza
    n = len(individuo)
    vector_prueba = np.zeros((n))
    j_rand = random.randint(0, n-1)
    for i in range(n):
        if random.random()  < CR or i == j_rand:
            vector_prueba[i]  = vector_mutante[i]
        else:
            vector_prueba[i] = individuo[i]
    return vector_prueba

# %%
# FUNCION SELECCION
def seleccion(individuo, vector_prueba):
    f1 = easom_function(individuo[0], individuo[1])
    f2 = easom_function(vector_prueba[0], vector_prueba[1])
    if f2 < f1:
        return vector_prueba
    else:
        return individuo

# %%
# ================= IMPLEMENTACION DEL ALGORITMO =================
tamaño_poblacion = 100
Imax = 5
Imin = -Imax
F = 0.8
CR = 0.9
generaciones = 100


hisotrico_fitness = []


poblacion = iniciar_poblacion(tamaño_poblacion, 2, Imin, Imax)
for g in range(generaciones):
    nueva_poblacion = np.zeros((tamaño_poblacion, 2))
    for i in range(tamaño_poblacion):
        mutacion_vector = mutacion(poblacion, F,i)
        vector_prueba = cruza(poblacion[i], mutacion_vector, CR)
        nuevo_individuo = seleccion(poblacion[i], vector_prueba)
        nueva_poblacion[i] = nuevo_individuo
    poblacion = nueva_poblacion
    mejor_fitness = np.min(evaluar(poblacion))
    mejor_fitness_indice = np.argmin(evaluar(poblacion))
    mejor_valor = poblacion[mejor_fitness_indice]
    hisotrico_fitness.append(mejor_fitness)
    
    print(f"Generacion {g+1}, Mejor fitness: {mejor_fitness} en {mejor_valor}")
# Out:
# Generacion 1, Mejor fitness: -0.6662576567025734 en [3.27200613 2.64161927]
# Generacion 2, Mejor fitness: -0.7416917830948299 en [2.94093366 2.74482849]
# Generacion 3, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 4, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 5, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 6, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 7, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 8, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 9, Mejor fitness: -0.7966605819614186 en [3.47566361 3.33945198]
# Generacion 10, Mejor fitness: -0.9289991677836607 en [3.35375624 3.20460132]
# Generacion 11, Mejor fitness: -0.9289991677836607 en [3.35375624 3.20460132]
# Generacion 12, Mejor fitness: -0.9289991677836607 en [3.35375624 3.20460132]
# Generacion 13, Mejor fitness: -0.9818756005322848 en [3.24480208 3.10241187]
# Generacion 14, Mejor fitness: -0.9818756005322848 en [3.24480208 3.10241187]
# Generacion 15, Mejor fitness: -0.9818756005322848 en [3.24480208 3.10241187]
# Generacion 16, Mejor fitness: -0.9818756005322848 en [3.24480208 3.10241187]
# Generacion 17, Mejor fitness: -0.9818756005322848 en [3.24480208 3.10241187]
# Generacion 18, Mejor fitness: -0.9852152902211622 en [3.06783362 3.20857698]
# Generacion 19, Mejor fitness: -0.9918261180238893 en [3.17295464 3.20857698]
# Generacion 20, Mejor fitness: -0.9977820371206668 en [3.12742001 3.17736034]
# Generacion 21, Mejor fitness: -0.9992445478718509 en [3.15545996 3.15924245]
# Generacion 22, Mejor fitness: -0.9992445478718509 en [3.15545996 3.15924245]
# Generacion 23, Mejor fitness: -0.999647667927086 en [3.13754975 3.12680815]
# Generacion 24, Mejor fitness: -0.999647667927086 en [3.13754975 3.12680815]
# Generacion 25, Mejor fitness: -0.999647667927086 en [3.13754975 3.12680815]
# Generacion 26, Mejor fitness: -0.999647667927086 en [3.13754975 3.12680815]
# Generacion 27, Mejor fitness: -0.9998580605033072 en [3.13473682 3.13469118]
# Generacion 28, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 29, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 30, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 31, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 32, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 33, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 34, Mejor fitness: -0.9999669675853063 en [3.13725236 3.13980834]
# Generacion 35, Mejor fitness: -0.999980756806086 en [3.13801137 3.14153514]
# Generacion 36, Mejor fitness: -0.999980756806086 en [3.13801137 3.14153514]
# Generacion 37, Mejor fitness: -0.999980756806086 en [3.13801137 3.14153514]
# Generacion 38, Mejor fitness: -0.999998854053709 en [3.14126682 3.1424037 ]
# Generacion 39, Mejor fitness: -0.999998854053709 en [3.14126682 3.1424037 ]
# Generacion 40, Mejor fitness: -0.999998854053709 en [3.14126682 3.1424037 ]
# Generacion 41, Mejor fitness: -0.999998854053709 en [3.14126682 3.1424037 ]
# Generacion 42, Mejor fitness: -0.9999997302373166 en [3.1419754  3.14141004]
# Generacion 43, Mejor fitness: -0.9999997302373166 en [3.1419754  3.14141004]
# Generacion 44, Mejor fitness: -0.9999997302373166 en [3.1419754  3.14141004]
# Generacion 45, Mejor fitness: -0.9999997302373166 en [3.1419754  3.14141004]
# Generacion 46, Mejor fitness: -0.9999997302373166 en [3.1419754  3.14141004]
# Generacion 47, Mejor fitness: -0.9999997316939405 en [3.14166733 3.14200894]
# Generacion 48, Mejor fitness: -0.9999999277422814 en [3.14164515 3.14180576]
# Generacion 49, Mejor fitness: -0.9999999908291363 en [3.14162719 3.1415225 ]
# Generacion 50, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 51, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 52, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 53, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 54, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 55, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 56, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 57, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 58, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 59, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 60, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 61, Mejor fitness: -0.9999999985691654 en [3.14156319 3.14160191]
# Generacion 62, Mejor fitness: -0.9999999989119156 en [3.14161554 3.14157846]
# Generacion 63, Mejor fitness: -0.9999999998159321 en [3.14160105 3.14159988]
# Generacion 64, Mejor fitness: -0.9999999999459432 en [3.141587   3.14159064]
# Generacion 65, Mejor fitness: -0.9999999999459432 en [3.141587   3.14159064]
# Generacion 66, Mejor fitness: -0.9999999999459432 en [3.141587   3.14159064]
# Generacion 67, Mejor fitness: -0.9999999999546766 en [3.14158786 3.14158997]
# Generacion 68, Mejor fitness: -0.9999999999546766 en [3.14158786 3.14158997]
# Generacion 69, Mejor fitness: -0.9999999999546766 en [3.14158786 3.14158997]
# Generacion 70, Mejor fitness: -0.9999999999546766 en [3.14158786 3.14158997]
# Generacion 71, Mejor fitness: -0.9999999999897125 en [3.14159146 3.14159499]
# Generacion 72, Mejor fitness: -0.9999999999897125 en [3.14159146 3.14159499]
# Generacion 73, Mejor fitness: -0.9999999999897125 en [3.14159146 3.14159499]
# Generacion 74, Mejor fitness: -0.9999999999923881 en [3.14159394 3.14159081]
# Generacion 75, Mejor fitness: -0.9999999999929778 en [3.14159081 3.14159379]
# Generacion 76, Mejor fitness: -0.9999999999947825 en [3.14159337 3.14159438]
# Generacion 77, Mejor fitness: -0.9999999999947825 en [3.14159337 3.14159438]
# Generacion 78, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 79, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 80, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 81, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 82, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 83, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 84, Mejor fitness: -0.999999999999328 en [3.141593   3.14159208]
# Generacion 85, Mejor fitness: -0.9999999999997606 en [3.14159286 3.14159299]
# Generacion 86, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 87, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 88, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 89, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 90, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 91, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 92, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 93, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 94, Mejor fitness: -0.999999999999989 en [3.14159273 3.14159262]
# Generacion 95, Mejor fitness: -0.9999999999999936 en [3.14159268 3.14159259]
# Generacion 96, Mejor fitness: -0.9999999999999936 en [3.14159268 3.14159259]
# Generacion 97, Mejor fitness: -0.9999999999999984 en [3.14159266 3.14159269]
# Generacion 98, Mejor fitness: -0.9999999999999984 en [3.14159266 3.14159269]
# Generacion 99, Mejor fitness: -0.9999999999999984 en [3.14159266 3.14159269]
# Generacion 100, Mejor fitness: -0.9999999999999984 en [3.14159266 3.14159269]

# %%
# Grafica de la evolucion del fitness
fig2 = go.Figure()
fig2.add_trace(go.Scatter(y=hisotrico_fitness, mode='lines+markers', name='Mejor Fitness'))
fig2.update_layout(title='Evolución del Mejor Fitness',
                   xaxis_title='Generación',
                   yaxis_title='Mejor Fitness')
fig2.show()
